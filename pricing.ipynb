# %%
import pandas as pd

# %%
file = 'datasets/ted_pricing.csv'

df = pd.read_csv(file)

df
# Out:
#     product_id                    product_name     category       brand  \
# 0     PROD0001       Apple Smartphone Modelo 1  Smartphones       Apple
# 1     PROD0002    Motorola Smartphone Modelo 2  Smartphones    Motorola
# 2     PROD0003     Samsung Smartphone Modelo 3  Smartphones     Samsung
# 3     PROD0004      Xiaomi Smartphone Modelo 4  Smartphones      Xiaomi
# 4     PROD0005      Realme Smartphone Modelo 5  Smartphones      Realme
# ..         ...                             ...          ...         ...
# 105   PROD0106       Anker Acessório Modelo 26   Acessórios       Anker
# 106   PROD0107      Baseus Acessório Modelo 27   Acessórios      Baseus
# 107   PROD0108    Logitech Acessório Modelo 28   Acessórios    Logitech
# 108   PROD0109  Multilaser Acessório Modelo 29   Acessórios  Multilaser
# 109   PROD0110      Geonav Acessório Modelo 30   Acessórios      Geonav
#
#      current_price     cost  margin_pct  units_sold_last_month  \
# ...
